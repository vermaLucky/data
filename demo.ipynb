# %%
import matplotlib.pyplot as py
from sklearn import datasets
from sklearn import svm

digit=datasets.load_digits()
print(digit.data)
print(digit.target)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]

# %%
from sklearn import datasets
from sklearn import svm
Iris=datasets.load_iris()
#Iris.feature_names
Iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
import matplotlib.pyplot as py
from sklearn import datasets
from sklearn import svm
digit=datasets.load_digits()
clf=svm.SVC()
print(len(digit.data))
x,y=digit.data[:-1],digit.target[:-1]
clf.fit(x,y)
print('prediction',clf.predict(digit.data[0:-1]))
py.imshow(digit.images[7],cmap=py.cm.gray_r,interpolation="bicubic")
py.show()
# Out:
# 1797
# prediction [0 1 2 ... 0 8 9]
